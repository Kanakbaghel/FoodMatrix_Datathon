# %% [markdown]
# # FoodMatrix — Getting Started
# ### Women in Data Datathon 2026 | Track: Trade
#
# This notebook is a starting template for our exploratory data analysis (EDA). Once the official FAOSTAT trade dataset is released at kickoff (Aug 18), update the data loading section below and start exploring.

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 2. Load Data
#
# Place raw FAOSTAT CSV/Excel files in `../data/raw/` and load them here.

# %%
# Example — update filename once dataset is available
# df = pd.read_csv('../data/raw/faostat_trade_data.csv')
# df.head()

# %% [markdown]
# ## 3. Initial Exploration

# %%
# df.info()
# df.describe()
# df.isnull().sum()

# %% [markdown]
# ## 4. Notes & Next Steps
#
# - [ ] Load official dataset once released
# - [ ] Identify key trade variables (import/export volume, partner countries, value)
# - [ ] Define the specific research question
# - [ ] Clean and structure data (assign to Yash)
# - [ ] Begin exploratory analysis
